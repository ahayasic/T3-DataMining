# %% [markdown]
# # 1. Introdução
# Criptomoedas são moedas digitais descentralizadas
# * moedas, por serem utilizadas para transações monetárias,
# * digitais, por não serem físicas e circularem em redes digitais
# * descentralizadas, pois não precisam de mediadores como bancos ou governos (entidade central) para validar suas transações.
#
# Em 1998 surgiram ideias para moedas digitais como o B-money e Bit Gold. Porém, a primeira moeda digital descentralizada foi criada em 2009 por Satoshi Nakamoto, chamada de BitCoin. A Bitcoin foi projetada para ser uma carteira digital, onde cada transação feita é guardado o valor, a data, o vendedor e o comprador.
# Inicialmente possuía um apelo mais ideológico que prático, principalmente para libertários por ser uma moeda descentralizada. Começou a ser usada em massa para comércio ilegal em mercados negros online, porém eventualmente começou a ser utilizada para poupança.
#
# Países com problemas de cambio ou crises economícas, incentivaram o uso do BitCoin para ser utilizado como forma de poupança, elevando exponencialmente o valor da moeda. Bitcoins comprados por 50 doláres em 2010 se valorizaram para 40 milhões de doláres em 2017, se tornando uma criptomoeda extremamente atraente para investimentos em poupança.
#
# Em 2011, surgiram mais de 900 tipos de criptomoedas, conhecidas como AltCoins, para satisfazer outras necessidades que a Bitcoin se tornara inapropriada, como por exemplo transações rápidas e leves. Ethereum é a segunda criptomoeda com maior capital, a característica marcante dessa moeda é que ela é usada não somente para transações como também para execução de código distribuído ou aplicação na rede Ethereum, surgiu em 2015. A terceira criptomoeda com maior capital é a XRP utilizada para o protocolo de pagamento Ripple, usada principalmente por bancos por sua segurança e livro-razão distribuídos (informação sobre a transação). Permite uso de Tokens para a troca para outras criptomoedas, moedas e milhas de voo e entre outros, surgiu em 2012.
#
# Outra criptomoeda interessante é o Bitcoin Cash, criado como fork do Bitcoin portanto duplicando a reserva de quem tinha Bitcoin e renomeando para Bitcoin Cash. Seu fork foi criado para aumentar o tamanho do Block e o número de transações por bloco, surgiu em 2017. Por último a Litecoin, é uma criptomoeda criada para transições mais rápidas que o Bitcoin porém são mais custosas para serem produziadas, surgiu em 2011.
#
# A capitalização dessas cinco criptomoedas (Bitcoin, Ethereum, XRP, Bitcoin Cash, Litecoin) serão estudadas nesse trabalho. Será importante saber também das bolhas ocorridas na história das criptomoedas.

# %% [markdown]
# # 3. Conjunto de Dados
#
#
# O conjunto de dados utilizados foi o fornecido pelo [Coin Market Cap](https://coinmarketcap.com/pt-br/) um site internacional que possui diversos dados relevantes sobre mais de 2095 criptomoedas desde sua criação e um dos mais utilizados por investidores em criptomoedas.
#
# Cada amostra do conjunto de dados é uma observação sobre uma criptomoeda em uma data específica. Ou seja, cada amostra possui:
# * - sigla (symbol): Sigla da criptomoeda amostrada
# * - nome (name): Nome da criptomoeda amostrada
# * - date (data): Data, no formato AAAA/MM/DD, em que a amostragem foi realizada
# * - ranknow : Rank da criptomoeda na data observada
# * - open (abertura): Valor (em dólares) de abertura da criptomoeda na data.
# * - high (alta): Valor (em dólares) mais alto da criptomoeda na data.
# * - low (baixa): Valor (em dólares) mais baixo da criptomoeda na data.
# * - close (fechamento): Valor (em dólares) da criptomoeda na última transação do dia.
# * - volume: Quantidade (em dólares) de criptomoeda que foi negociada sobre 24hrs.
# * - market (Capitalização de Mercado): É uma forma de ranquear o tamanho de uma criptomoeda. A capitalização de mercado refere-se ao produto da quantidade de moedas existentes com o seu valor na data.
# * - close_ratio (Taxa de fechamento): Taxa aproximada de fechamento
# * - spread : Diferença, em dólares, do valor mais alto e mais baixo registrados nos dia.

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

# %%
df = pd.read_csv('crypto-markets.csv')
df
# Out:
#                 slug symbol          name        date  ranknow        open  \
# 0            bitcoin    BTC       Bitcoin  2013-04-28        1  135.300000
# 1            bitcoin    BTC       Bitcoin  2013-04-29        1  134.440000
# 2            bitcoin    BTC       Bitcoin  2013-04-30        1  144.000000
# 3            bitcoin    BTC       Bitcoin  2013-05-01        1  139.000000
# 4            bitcoin    BTC       Bitcoin  2013-05-02        1  116.380000
# 5            bitcoin    BTC       Bitcoin  2013-05-03        1  106.250000
# 6            bitcoin    BTC       Bitcoin  2013-05-04        1   98.100000
# 7            bitcoin    BTC       Bitcoin  2013-05-05        1  112.900000
# 8            bitcoin    BTC       Bitcoin  2013-05-06        1  115.980000
# 9            bitcoin    BTC       Bitcoin  2013-05-07        1  112.250000
# 10           bitcoin    BTC       Bitcoin  2013-05-08        1  109.600000
# ...

# %%
df['symbol'].value_counts()
# Out:
# NET      1955
# NMC      1866
# BTC      1866
# LTC      1866
# NVC      1865
# PPC      1865
# FTC      1861
# TRC      1851
# BTB      1838
# WDC      1827
# DGC      1823
# GLD      1812
# XPM      1792
# MEC      1791
# PXC      1774
# ANC      1772
# XRP      1768
# FRC      1767
# IXC      1764
# CBX      1763
# IFC      1754
# QRK      1745
# ZET      1727
# FST      1700
# BTM      1691
# TAG      1675
# ARG      1664
# FLO      1653
# CSC      1652
# NXT      1646
#          ...
# FT         15
# XRH        15
# INV        15
# GIN        15
# APIS       15
# IOTX       13
# NKN        10
# REPO       10
# SOUL       10
# AVA        10
# NAVI       10
# ZIP        10
# LUC        10
# EXC        10
# FACE       10
# NEC         8
# IVY         7
# SEELE       7
# CNET        7
# EJOY        7
# QKC         3
# SHOP        3
# 0XBTC       3
# PAI         3
# BBO         3
# CPT         2
# ETZ         2
# LYL         2
# BNK         2
# MEDX        1
# ...

# %% [markdown]
# No total, existem 785 024 objetos no conjunto de dados divididos em 1605 criptomoedas diferentes. Portanto, devido a grande a quantidade de criptomoedas que poderiam ser analisadas, foram escolhidas apenas as 5 criptomoedas mais influentes e melhores ranqueadas até a data deste trabalho (14/11/2017), são elas:
# * Bitcoin (BTC)
# * Ethereum (ETH)
# * XRP (XRP)
# * Bitcoin Cash (BCH)
# * Litecoins (LTC)
#
# O conjunto de dados apenas com essas 5 moedas possui um total de 6854 objetos, sendo:
# - 1866 Bitcoins (BTC)
# - 1866 Litecoins (LTC)
# - 1768 XRP (XRP)
# - 1035 Ethereum (ETH)
# - 319  Bitcoin Cash (BCH)

# %%
coins = ['BTC', 'ETH', 'XRP', 'BCH', 'LTC']
data = df.loc[df['symbol'].isin(coins)]
data
# Out:
#           slug symbol      name        date  ranknow    open    high     low  \
# 0      bitcoin    BTC   Bitcoin  2013-04-28        1  135.30  135.98  132.10
# 1      bitcoin    BTC   Bitcoin  2013-04-29        1  134.44  147.49  134.00
# 2      bitcoin    BTC   Bitcoin  2013-04-30        1  144.00  146.93  134.05
# 3      bitcoin    BTC   Bitcoin  2013-05-01        1  139.00  139.89  107.72
# 4      bitcoin    BTC   Bitcoin  2013-05-02        1  116.38  125.60   92.28
# 5      bitcoin    BTC   Bitcoin  2013-05-03        1  106.25  108.13   79.10
# 6      bitcoin    BTC   Bitcoin  2013-05-04        1   98.10  115.00   92.50
# 7      bitcoin    BTC   Bitcoin  2013-05-05        1  112.90  118.80  107.14
# 8      bitcoin    BTC   Bitcoin  2013-05-06        1  115.98  124.66  106.64
# 9      bitcoin    BTC   Bitcoin  2013-05-07        1  112.25  113.44   97.70
# 10     bitcoin    BTC   Bitcoin  2013-05-08        1  109.60  115.78  109.60
# ...

# %%
data['symbol'].value_counts()
# Out:
# LTC    1866
# BTC    1866
# XRP    1768
# ETH    1035
# BCH     319
# Name: symbol, dtype: int64

# %% [markdown]
# Uma vez que as criptomoedas que serão analisadas foram montadas em um conjunto de dados específico, torna-se necessário avaliar a integridade dos dados e extrair informações prévias através de estatísticas de resumo.
#
# Assim, o primeiro passo foi verificar se existiam valores faltantes no conjunto de dados e, em seguida, verificou-se uma descrição sobre os dados para verificar valores inconsistentes, como por exemplo, valores de abertura, fechamento, alta e baixa que são em dólares, negativos.

# %%
data.isna().any()
# Out:
# slug           False
# symbol         False
# name           False
# date           False
# ranknow        False
# open           False
# high           False
# low            False
# close          False
# volume         False
# market         False
# close_ratio    False
# spread         False
# dtype: bool

# %%
data.describe()
# Out:
#            ranknow          open          high           low         close  \
# count  6854.000000   6854.000000   6854.000000   6854.000000   6854.000000
# mean      3.167785    602.036876    625.354093    576.577568    603.206240
# std       1.925925   1925.212536   2003.631008   1831.131629   1926.835955
# min       1.000000      0.002809      0.003082      0.002802      0.002810
# 25%       1.000000      0.814681      0.860717      0.770347      0.813906
# 50%       3.000000     10.975000     11.255000     10.590000     11.000000
# 75%       6.000000    381.650000    391.307500    371.092500    381.145000
# max       6.000000  19475.800000  20089.000000  18974.100000  19497.400000
#
#              volume        market  close_ratio       spread
# count  6.854000e+03  6.854000e+03  6854.000000  6854.000000
# mean   5.463150e+08  1.381961e+10     0.506689    48.776436
# std    1.778522e+09  3.440672e+10     0.311950   206.848892
# ...

# %% [markdown]
# A correlação entre os atributos também é um fator importante, principalmente quando trata-se do mercado financeiro. Portanto, é natural e esperado que os atributos relacionados ao preço da criptomoedas em uma data específica sejam altamente correlacionados (como mostra a tabela). Além disso, também há uma alta correlação dos preços das criptomoedas com o volume e capitalização do mercado, indicando uma possível bem-sucedida análise de regressão e previsão entre os valores dos atributos.
#
# A correlação entre volume e capitalização de mercado (market) também fornece a informação de que quanto maior o volume maior a capitalização da moeda e vice-versa.
#
# Contudo, apesar da boa correlação dos dados e as informações que eles nos fornecem, estamos partindo de um ponto de vista generalizado pois, é necessário visualizar cada criptomoeda unicamente e seu impacto nas outras criptomoedas.

# %%
data.corr()
# Out:
#               ranknow      open      high       low     close    volume  \
# ranknow      1.000000 -0.292217 -0.290186 -0.295640 -0.292572 -0.202767
# open        -0.292217  1.000000  0.998960  0.998245  0.997762  0.878369
# high        -0.290186  0.998960  1.000000  0.998224  0.999222  0.882607
# low         -0.295640  0.998245  0.998224  1.000000  0.998860  0.869180
# close       -0.292572  0.997762  0.999222  0.998860  1.000000  0.877387
# volume      -0.202767  0.878369  0.882607  0.869180  0.877387  1.000000
# market      -0.300524  0.928414  0.927541  0.926409  0.926189  0.925907
# close_ratio -0.057513  0.036147  0.041238  0.041772  0.048904  0.045589
# spread      -0.193718  0.839408  0.849659  0.816738  0.836496  0.854896
#
#                market  close_ratio    spread
# ranknow     -0.300524    -0.057513 -0.193718
# open         0.928414     0.036147  0.839408
# high         0.927541     0.041238  0.849659
# low          0.926409     0.041772  0.816738
# ...

# %%
btc = data.loc[data['symbol']=='BTC']
eth = data.loc[data['symbol']=='ETH']
xrp = data.loc[data['symbol']=='XRP']
bch = data.loc[data['symbol']=='BCH']
ltc = data.loc[data['symbol']=='LTC']

btc_dates = pd.to_datetime(btc['date'])
eth_dates = pd.to_datetime(eth['date'])
xrp_dates = pd.to_datetime(xrp['date'])
bch_dates = pd.to_datetime(bch['date'])
ltc_dates = pd.to_datetime(ltc['date'])

# %% [markdown]
# Verificando, portanto, as Bitcoins inicialmente, é possível recuperar algumas informações importantes, como:
#
# * Quando criadas, as Bitcoins começaram inicialmente com um valor de USD 135.30, com uma alta de USD 135.98, baixa de USD 132.10 e fechando em USD 134.21. Contudo, a BTC chegou a uma queda absurda de USD 68.50 no valor de abertura. [1]
# * Em contra partida da queda, o maior valor registrado para a Bitcoin foi de USD 20 089.00, indicando um crescimento gigantesco desde sua criação em 2013. [2]

# %%
btc.describe()
# Out:
#        ranknow          open          high           low         close  \
# count   1866.0   1866.000000   1866.000000   1866.000000   1866.000000
# mean       1.0   1885.744502   1951.660102   1812.283730   1889.513762
# std        0.0   3321.359095   3458.838432   3153.471445   3323.418678
# min        1.0     68.500000     74.560000     65.530000     68.430000
# 25%        1.0    284.857500    291.127500    280.985000    285.310000
# 50%        1.0    565.950000    576.295000    535.000000    565.975000
# 75%        1.0   1055.210000   1094.930000   1034.742500   1059.617500
# max        1.0  19475.800000  20089.000000  18974.100000  19497.400000
#
#              volume        market  close_ratio       spread
# count  1.866000e+03  1.866000e+03  1866.000000  1866.000000
# mean   1.171548e+09  3.078214e+10     0.544563   139.376372
# std    3.023214e+09  5.621236e+10     0.299849   367.792599
# min    0.000000e+00  7.792550e+08     0.000000     0.000000
# ...

# %%
btc.loc[btc['date']=='2017-01-01']
# Out:
#          slug symbol     name        date  ranknow    open     high    low  \
# 1344  bitcoin    BTC  Bitcoin  2017-01-01        1  963.66  1003.08  958.7
#
#        close       volume        market  close_ratio  spread
# 1344  998.33  147775000.0  1.549120e+10        0.893   44.38

# %%
btc.loc[btc['date']=='2017-12-31']
# Out:
#          slug symbol     name        date  ranknow     open     high      low  \
# 1708  bitcoin    BTC  Bitcoin  2017-12-31        1  12897.7  14377.4  12755.6
#
#         close        volume        market  close_ratio  spread
# 1708  14156.4  1.213630e+10  2.163260e+11       0.8637  1621.8

# %%
eth.describe()
# Out:
#        ranknow         open         high          low        close  \
# count   1035.0  1035.000000  1035.000000  1035.000000  1035.000000
# mean       2.0   196.389495   205.027354   186.856956   196.889603
# std        0.0   292.818747   306.265505   277.055802   292.880268
# min        2.0     0.431589     0.482988     0.420897     0.434829
# 25%        2.0     8.610000     8.905000     8.240000     8.625000
# 50%        2.0    13.060000    13.350000    12.640000    13.070000
# 75%        2.0   304.430000   313.440000   295.345000   305.400000
# max        2.0  1397.480000  1432.880000  1290.600000  1396.420000
#
#              volume        market  close_ratio       spread
# count  1.035000e+03  1.035000e+03  1035.000000  1035.000000
# mean   7.075375e+08  1.892582e+10     0.524223    18.170396
# std    1.279721e+09  2.859274e+10     0.297310    37.186458
# min    1.021280e+05  0.000000e+00     0.000000     0.020000
# 25%    7.564170e+06  7.204790e+08     0.267450     0.315000
# ...

# %%
eth.loc[eth['date']=='2017-01-01']
# Out:
#           slug symbol      name        date  ranknow  open  high   low  close  \
# 2379  ethereum    ETH  Ethereum  2017-01-01        2  7.98  8.47  7.98   8.17
#
#           volume       market  close_ratio  spread
# 2379  14731700.0  698149000.0       0.3878    0.49

# %%
eth.loc[eth['date']=='2017-12-31']
# Out:
#           slug symbol      name        date  ranknow    open    high     low  \
# 2743  ethereum    ETH  Ethereum  2017-12-31        2  712.21  760.35  710.12
#
#        close        volume        market  close_ratio  spread
# 2743  756.73  2.554270e+09  6.885080e+10       0.9279   50.23

# %%
xrp.describe()
# Out:
#        ranknow         open         high          low        close  \
# count   1768.0  1768.000000  1768.000000  1768.000000  1768.000000
# mean       3.0     0.135752     0.144776     0.126519     0.136143
# std        0.0     0.346423     0.376911     0.317183     0.346687
# min        3.0     0.002809     0.003082     0.002802     0.002810
# 25%        3.0     0.006147     0.006313     0.006022     0.006161
# 50%        3.0     0.008065     0.008255     0.007973     0.008077
# 75%        3.0     0.031279     0.033306     0.028615     0.031480
# max        3.0     3.360000     3.840000     3.120000     3.380000
#
#              volume        market  close_ratio       spread
# count  1.768000e+03  1.768000e+03  1768.000000  1768.000000
# mean   1.719680e+08  5.168853e+09     0.474505     0.017913
# std    7.012786e+08  1.349329e+10     0.340775     0.074813
# min    0.000000e+00  2.196030e+07     0.000000     0.000000
# 25%    2.415525e+05  1.552675e+08     0.151350     0.000000
# ...

# %%
xrp.loc[xrp['date']=='2017-01-01']
# Out:
#         slug symbol    name        date  ranknow      open      high  \
# 4147  ripple    XRP  Ripple  2017-01-01        3  0.006523  0.006702
#
#            low     close    volume       market  close_ratio  spread
# 4147  0.006334  0.006368  418978.0  237032000.0       0.0924     0.0

# %%
xrp.loc[xrp['date']=='2017-12-31']
# Out:
#         slug symbol    name        date  ranknow  open  high   low  close  \
# 4511  ripple    XRP  Ripple  2017-12-31        3   2.1  2.39  1.87    2.3
#
#             volume        market  close_ratio  spread
# 4511  4.642080e+09  8.116260e+10       0.8269    0.52

# %%
bch.describe()
# Out:
#        ranknow         open         high          low        close  \
# count    319.0   319.000000   319.000000   319.000000   319.000000
# mean       4.0  1103.624608  1182.859091  1026.103824  1104.780376
# std        0.0   689.160609   747.347465   625.314618   687.738979
# min        4.0   212.180000   223.700000   200.980000   213.150000
# 25%        4.0   540.155000   592.740000   502.880000   539.760000
# 50%        4.0  1015.680000  1087.300000   975.400000  1019.430000
# 75%        4.0  1432.360000  1515.375000  1338.605000  1431.975000
# max        4.0  3909.000000  4355.620000  3038.010000  3923.070000
#
#              volume        market  close_ratio       spread
# count  3.190000e+02  3.190000e+02   319.000000   319.000000
# mean   9.292763e+08  1.845137e+10     0.477776   156.755266
# std    1.169337e+09  1.195632e+10     0.309227   187.949004
# min    8.501300e+04  0.000000e+00     0.000000     7.500000
# 25%    3.175855e+08  8.918395e+09     0.202450    53.770000
# ...

# %%
bch.loc[bch['date']=='2017-07-23']
# Out:
#               slug symbol          name        date  ranknow    open    high  \
# 4669  bitcoin-cash    BCH  Bitcoin Cash  2017-07-23        4  555.89  578.97
#
#          low   close   volume  market  close_ratio  spread
# 4669  411.78  413.06  85013.0     0.0       0.0077  167.19

# %%
bch.loc[bch['date']=='2017-12-31']
# Out:
#               slug symbol          name        date  ranknow     open  \
# 4830  bitcoin-cash    BCH  Bitcoin Cash  2017-12-31        4  2376.96
#
#          high      low    close        volume        market  close_ratio  \
# 4830  2627.95  2350.03  2533.01  1.300820e+09  4.013490e+10       0.6584
#
#       spread
# 4830  277.92

# %%
ltc.describe()
# Out:
#        ranknow         open         high          low        close  \
# count   1866.0  1866.000000  1866.000000  1866.000000  1866.000000
# mean       6.0    27.868232    29.253955    26.363055    27.918816
# std        0.0    55.357466    58.442231    51.922772    55.360696
# min        6.0     1.150000     1.340000     1.110000     1.160000
# 25%        6.0     3.180000     3.240000     3.092500     3.180000
# 50%        6.0     3.980000     4.080000     3.900000     3.980000
# 75%        6.0    19.220000    20.957500    17.200000    19.787500
# max        6.0   359.130000   375.290000   335.680000   358.340000
#
#              volume        market  close_ratio       spread
# count  1.866000e+03  1.866000e+03  1866.000000  1866.000000
# mean   1.208760e+08  1.429485e+09     0.494528     2.890900
# std    3.627559e+08  3.075594e+09     0.299087     8.464294
# min    0.000000e+00  3.794370e+07     0.000000     0.010000
# 25%    1.428832e+06  1.245332e+08     0.250000     0.080000
# ...

# %%
ltc.loc[ltc['date']=='2017-01-01']
# Out:
#           slug symbol      name        date  ranknow  open  high   low  close  \
# 6673  litecoin    LTC  Litecoin  2017-01-01        6  4.33  4.52  4.33   4.51
#
#           volume       market  close_ratio  spread
# 6673  11337500.0  212691000.0       0.9474    0.19

# %%
ltc.loc[ltc['date']=='2017-12-31']
# Out:
#           slug symbol      name        date  ranknow    open    high     low  \
# 7037  litecoin    LTC  Litecoin  2017-12-31        6  216.97  237.79  213.81
#
#       close       volume        market  close_ratio  spread
# 7037  232.1  771042000.0  1.183510e+10       0.7627   23.98

# %% [markdown]
# Posto que os valores em uma tabela de descrição pode não nos informar muito sobre o comportamento e preço de uma criptomoeda, a criação de um gráfico pode tornar a extração de informação muito mais simples.
#
# As células abaixo referem-se ao valor de fechamento das 5 criptomoedas analisadas ao longo dos anos (e desde sua criação).
#
# Diversas informações relevantes podem ser retiradas através desses gráficos com apoio de consultas no conjunto de dados:
# * Nota-se, claramente, que não apenas o preço mas a valorização das Bitcoins são absurdamente mais altas do que qualquer outra criptomoeda.
#
# * O maior valor de fechamento de uma criptomoeda foi da Bitcoin com USD 19497.40, a segunda criptomoeda com maior valor de fechamento foi a Bitcoin Cash com USD 3923.07, seguida da Ethereum com USD 1396.42. A diferença em dólares da BTC em seu pico para a BCH é de USD 15574.33
#
# * A valorização e desvalorização das criptomoedas ocorrem em períodos extremamente parecidos com uma certa predisposição as variações da BTC. Isto é, a partir do momento em que a Bitcoin começa a valorizar, as outras criptomoedas também passam a ser valorizadas. Caso a Bitcoin se desvalorize, o mesmo ocorre com as outras moedas.
#
# * No ano de 2017, a BTC passou por um processo de super valorização, abrindo o ano em USD 963.66 e alcançando a marca de USD 19497.40 e fechando o ano com USD 14156.40, ou seja, 14 vezes o valor inicial (ou 1400% de valorização).
#
# * A BCH abriu pela primeira vez em 23/07/2017 com USD 555.89 chegando a USD 3923.07 em 20/12/2017. Ou seja, a BCH valorizou 600% em 5 meses, o equivalente a 120% por mês.
#
# * A Ethereum e Litecoin valorizaram, respectivamente, 910% e 500% em 2017.
#
# * A criptomoeda que menos valorizou em 2017 foi a XRP (Ripple) com 360% de valorização.
#
# Apesar dessas informações serem extremamente interessantes, seu ponto fundamental é nos levar a seguinte pergunta. O que houve em 2017 para as criptomoedas valorizarem tanto?
#
# - No começo de 2013, uma cambiadora de criptomoedas chamada Mt. Gox era a principal responsável por fazer as transações em BitCoins, gerenciando cerca de 70% das transações de Bitcoins ao redor do mundo. Porém em 2014 a Mt. Gox suspenderam o saque de Bitcoins devido a um bug encontrado que permitiu o roubo de criptomoedas sem a detecção da rede. O preço do Bitcoin decaiu 36% durante esse período.
#
# - No final de 2013 também ocorreu uma outra bolha devido a popularidade ganha do Bitcoin na China, aumentando consideravelmente a quantidade de investidores e mineradores. Porém o governo  chinês proibiu o comércio de criptomoedas no país por serem moedas descentralizadas.
#
# - A última bolha ocorreu em 2017, com a desvalorização da moeda chinesa (Yuan) e o governo retirando a proibição devido a pressão bancária. Porém com a popularização de outras AltCoins.

# %%
plt.figure(figsize=(15,7))
plt.plot(btc_dates, btc['close'], color='#FFC312')
plt.plot(eth_dates, eth['close'], color='#2ecc71')
plt.plot(xrp_dates, xrp['close'], color='#0652DD')
plt.plot(bch_dates, bch['close'], color='#D980FA')
plt.plot(ltc_dates, ltc['close'], color='#EA2027')
plt.legend(['Bitcoin', 'Ethereum', 'XRP', 'Bitcoin Cash', 'Litecoin'], loc=0, fontsize='x-large')
plt.title('Valor de fechamento em dólares das Top 5 Criptomoedas desde sua criação', fontsize='xx-large')

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(eth_dates, eth['close'], color='#2ecc71')
plt.plot(xrp_dates, xrp['close'], color='#0652DD')
plt.plot(bch_dates, bch['close'], color='#D980FA')
plt.plot(ltc_dates, ltc['close'], color='#EA2027')
plt.legend(['Ethereum', 'XRP', 'Bitcoin Cash', 'Litecoin'], loc=0, fontsize='x-large')
plt.title('Valor de fechamento em dólares das criptomoedas Ethereum, XRP, Bitcoin Cash e Litecoin', fontsize='xx-large')

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(xrp_dates, xrp['close'], color='#0652DD')
plt.plot(ltc_dates, ltc['close'], color='#EA2027')
plt.legend(['XRP', 'Litecoin'], loc=0, fontsize='x-large')
plt.title('Valor de fechamento em dólares das criptomoedas XRP, Litecoin', fontsize='xx-large')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Os gráficos abaixam expressam o volume (em dólares) de transações feitas utilizando as criptomoedas tratadas neste trabalho (OBS: os gráficos estão em uma escala 1e-10).
#
# A partir do gráfico é possível perceber que quando houve a bolha do Bitcoin em 2017, o volume de transações foi imenso. Contudo, o pico de transações ocorreu somente em 05/01/2018 quando a criptomoeda abriu em UDS 15477.2 e fechou em USD 17429.5
#
# Após essa data a valorização da moeda começou a cair, justamente, pela super valorização alcançada nos dois meses anteriores e o alto número de vendas de Bitcoins.

# %%
plt.figure(figsize=(15,7))
plt.plot(btc_dates, btc['volume'], color='#FFC312')
plt.plot(eth_dates, eth['volume'], color='#2ecc71')
plt.plot(xrp_dates, xrp['volume'], color='#0652DD')
plt.plot(bch_dates, bch['volume'], color='#D980FA')
plt.plot(ltc_dates, ltc['volume'], color='#EA2027')
plt.legend(['Bitcoin', 'Ethereum', 'XRP', 'Bitcoin Cash', 'Litecoin'], loc=0, fontsize='x-large')
plt.title('Volume em dólares das Top 5 Criptomoedas desde sua criação', fontsize='xx-large')

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(eth_dates, eth['volume'], color='#2ecc71')
plt.plot(xrp_dates, xrp['volume'], color='#0652DD')
plt.plot(bch_dates, bch['volume'], color='#D980FA')
plt.plot(ltc_dates, ltc['volume'], color='#EA2027')
plt.legend(['Ethereum', 'XRP', 'Bitcoin Cash', 'Litecoin'], loc=0, fontsize='x-large')
plt.title('Volume em dólares das criptomoedas Ethereum, XRP, Bitcoin Cash e Litecoin', fontsize='xx-large')

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(xrp_dates, xrp['volume'], color='#0652DD')
plt.plot(ltc_dates, ltc['volume'], color='#EA2027')
plt.legend(['XRP', 'Litecoin'], loc=0, fontsize='x-large')
plt.title('Volume em dólares das criptomoedas XRP, Litecoin', fontsize='xx-large')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 4. Análise de Impacto e Regressão (Experimentos)
#
# A partir de todas as análises e informações coletadas até agora, é possível inferir que a Bitcoin é de longe a criptomoeda não apenas mais importante, como também, impactante, sendo seu valor de mercado altamente influenciador nas outras criptomoedas.
#
# Além disso, o desenvolvimento de um algoritmo capaz de predizer, por exemplo, o valor que uma criptomoeda vai fechar em determinado período de tempo (ou naquele mesmo dia) pode ser vantajoso para diversas relações de transação. Contudo, apesar de audacioso, o desenvolvimento de tal algoritmo é extremamente complexo pois, assim como foi o caso das bolhas, as variações do preço de uma criptomoeda estão sempre relacionadas com fatores externos, sejam eles políticos ou comerciais.
#
# Não o bastante, a falta de dados que descreva precisamente o comportamento das criptomoedas impede bruscamente o desenvolvimento de um regressor eficiente pra predizer valores de abertura e fechamento, por exemplo. Afinal, até 2017, a valorização das criptomoedas nunca foi tão alta quanto em 2017.
#
#
# Porém, isto não impede o desenvolvimento de um regressor orientado a influência de uma criptomoeda sobre a outra. Isto é, dado o valor de abertura, alta e baixa de um Bitcoin é possível prever o valor de fechamento da Ethereum ou Bitcoin Cash?
# Essa informação pode ser útil em diversas situações de transações, trocas de moedas e diversas outras estratégias financeiras, tal como, verificar se o comportamento de uma criptomoeda pode descrever o de outra.
#
# ### Estratégias
#
# Portanto, foi definido o seguinte objetivo: É possível determinar o preço de fechamento de uma criptomoeda em relação as informações de outra?
#
# Para isso, foi desenvolvido um regressor treinado com os dados de abertura, baixa e alta de uma criptomoeda e, testado nos dados de todas as outras criptomoedas. Por exemplo, no primeiro caso, treinou-se o regressor com dados da Bitcoin e testou seu poder de predição para a Ethereum, Bitcoin Cash, Ripple e Litocoin.
#
# O regressor adotado foi k Vizinhos Mais Próximos (em sua forma para regressão) cujo número de vizinhos adotado foi igual a 5. Já as métricas de avaliação adotadas foram:
# * Coeficiente de Determinação ($R^2$): Mede o quão bem o modelo é capaz de prever valores futuros. Caso seja 1, então o modelo possui uma capacidade de generalização perfeita. Além disso, apesar de raro, o Coeficiente de Determinação pode ser negativo.
# * Erro Quadrático Médio (MSE): O Erro Quadrático Médio é simplemente o somatório do valor de todos os erros do modelo, elevado ao quadrado. Como o MSE toma os valores de erro quadrados, a métrica é extremamente sensível a valores discrepantes, posto que os valores muito discrepantes levam a grandes erros.
# * Pontuação de variação explicada (EVS): Essa métrica mede o quão bem um modelo consegue predizer variações no conjunto de dados. O valor mais alto que a EVS pode alcamçar é 1 (nesse caso, se tem um regressor com uma grande capacidade de prever variações) e valores mais baixos expressam um pior desempenho.

# %% [markdown]
# ## 4.2. BTC x ETH, BCH, XRP e LTC
#
# O primeiro caso de treinamento e teste foi verificar a capacidade do Bitcoin de descrever o comportamento das outras criptomoedas. Portanto, 5-NN (kNN com 5 vizinhos mais próximos) foi treinado com os dados de abertura, alta, baixa e fechamento da Bitcoin em uma dia $x$ e testado com os dados de fechamento das demais criptomoedas, também no dia $x$.

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics   import mean_squared_error, explained_variance_score

np.random.seed(1)

# %%
x_train = btc.iloc[:,5:8]
y_train = btc.iloc[:,8]

x_test = [eth.iloc[:,5:8], xrp.iloc[:,5:8], bch.iloc[:,5:8], ltc.iloc[:,5:8]]
y_test = [eth.iloc[:,8], xrp.iloc[:,8], bch.iloc[:,8], ltc.iloc[:,8]]

clf = None
clf = KNeighborsRegressor(n_neighbors=5, weights='distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='distance')

# %%
results = []

for x, y in zip(x_test, y_test):
        y_pred = clf.predict(x)
        r2  = clf.score(x, y)
        mse = mean_squared_error(y, y_pred)
        evs = explained_variance_score(y, y_pred)
        aux = [r2, mse, evs, y_pred]
        results.append(aux)

# %%
for i in results:
    print('R²: {:.4f}\tMSE: {:.4f}\t EVS: {:.4f}'.format(i[0], i[1], i[2]))
# Out:
# R²: 0.9695	MSE: 2611.3261	 EVS: 0.9863
# R²: -44515.2056	MSE: 5347.4544	 EVS: -0.0009
# R²: 0.9877	MSE: 5781.9492	 EVS: 0.9878
# R²: -0.2117	MSE: 3711.5124	 EVS: 0.8081

# %%
plt.figure(figsize=(15,7))
plt.plot(eth_dates, y_test[0],     color='#2ecc71')
plt.plot(eth_dates, results[0][3], color='#FFC312')
plt.legend(['ETH (Close) Verdadeiro', 'ETH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(xrp_dates, y_test[1],     color='#0652DD')
plt.plot(xrp_dates, results[1][3], color='#FFC312')
plt.legend(['XRP (Close) Verdadeiro', 'XRP (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(bch_dates, y_test[2],     color='#D980FA')
plt.plot(bch_dates, results[2][3], color='#FFC312')
plt.legend(['BCH (Close) Verdadeiro', 'BCH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(ltc_dates, y_test[3],     color='#EA2027')
plt.plot(ltc_dates, results[3][3], color='#FFC312')
plt.legend(['LTC (Close) Verdadeiro', 'LTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Análise sobre os resultados
#
# A Tabela abaixo apresenta os resultados obtidos no primeiro caso
#
# | Criptomoeda | R Quadrado  | MSE       | EVS     |
# |-------------|-------------|-----------|---------|
# | Ethereum    | 0.9695      | 2611.3261 | 0.9863  |
# | Ripple      | -44515.2056 | 5347.4544 | -0.0009 |
# | B.Cash      | 0.9877      | 5781.9492 | 0.9878  |
# | Litecoin    |-0.2117      | 711.5124  | 0.8081  |
#
#
# Através da Tabela e dos gráficos apresentados acima é possível verificar que a partir do Bitcoin, é possível ter uma boa estimativa sobre o comportamento das criptomoedas Ethereum e Bitcoin Cash, principalmente. Isto é, as variações da BTC são muito parecidas com as variações da ETH e BCH demonstrando uma boa influência da BTC sobre elas. No entanto, no caso da ETH, isto ocorre somente a partir de 2017 pois, em períodos posteriores o regressor determinou com uma certa discrepância os valores da ETH.
#
# Já quanto as outras criptomoedas, é muito pouca ou quase nula o desempenho e relação da BTC.  No caso da XRP, pode-se inferir que apesar das variações das linhas serem semelhantes e distância entre os valores preditos é extremamente discrepante. Já para a LTC, há uma certa "demora" para os valores começarem a serem preditos, indicando que a LTC sofre impactos atrasados da BTC.

# %% [markdown]
# ## 4.3. ETH x BTC, BCH, XRP e LTC
#
# O segundo caso de treinamento e teste foi verificar a capacidade da Ethereum de descrever o comportamento das outras criptomoedas. Portanto, 5-NN (kNN com 5 vizinhos mais próximos) foi treinado com os dados de abertura, alta, baixa e fechamento da Ethereum em uma dia $x$ e testado com os dados de fechamento das demais criptomoedas, também no dia $x$.

# %%
x_train = eth.iloc[:,5:8]
y_train = eth.iloc[:,8]

x_test = [btc.iloc[:,5:8], xrp.iloc[:,5:8], bch.iloc[:,5:8], ltc.iloc[:,5:8]]
y_test = [btc.iloc[:,8], xrp.iloc[:,8], bch.iloc[:,8], ltc.iloc[:,8]]

clf = None
clf = KNeighborsRegressor(n_neighbors=5, weights='distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='distance')

# %%
results = []

for x, y in zip(x_test, y_test):
        y_pred = clf.predict(x)
        r2  = clf.score(x, y)
        mse = mean_squared_error(y, y_pred)
        evs = explained_variance_score(y, y_pred)
        aux = [r2, mse, evs, y_pred]
        results.append(aux)

# %%
for i in results:
    print('R²: {:.4f}\tMSE: {:.4f}\t EVS: {:.4f}'.format(i[0], i[1], i[2]))
# Out:
# R²: 0.0211	MSE: 10806789.3728	 EVS: 0.1600
# R²: -0.6173	MSE: 0.1943	 EVS: 0.7924
# R²: 0.5373	MSE: 218184.3542	 EVS: 0.6102
# R²: 0.9960	MSE: 12.1834	 EVS: 0.9961

# %%
plt.figure(figsize=(15,7))
plt.plot(btc_dates, y_test[0],     color='#FFC312')
plt.plot(btc_dates, results[0][3], color='#2ecc71')
plt.legend(['BTC (Close) Verdadeiro', 'BTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Ethereum', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(xrp_dates, y_test[1],     color='#0652DD')
plt.plot(xrp_dates, results[1][3], color='#2ecc71')
plt.legend(['XRP (Close) Verdadeiro', 'XRP (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Ethereum', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(bch_dates, y_test[2],     color='#D980FA')
plt.plot(bch_dates, results[2][3], color='#2ecc71')
plt.legend(['BCH (Close) Verdadeiro', 'BCH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Ethereum', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(ltc_dates, y_test[3],     color='#EA2027')
plt.plot(ltc_dates, results[3][3], color='#2ecc71')
plt.legend(['LTC (Close) Verdadeiro', 'LTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Ethereum', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Análise sobre os resultados
#
# A Tabela abaixo apresenta os resultados obtidos no segundo caso
#
# | Criptomoeda | R Quadrado  | MSE         | EVS     |
# |-------------|-------------|-------------|---------|
# | Bit Coin    | 0.0211      | 108068.3728 | 0.1600  |
# | Ripple      | -0.6173     | 0.1943      | 0.7924  |
# | B.Cash      | 0.5373      | 218184.3542 | 0.6102  |
# | Litecoin    |  0.9960     | 12.1834     | 0.9961  |
#
# Assim como ocorreu no primeiro caso, através da Tabela e dos gráficos apresentados acima, é possível verificar que a partir da Etherem, é possível ter uma boa estimativa sobre o comportamento da Litecoin.
#
# Já quanto as outras criptomoedas, é muito pouca ou quase nula o desempenho e relação da ETH.

# %% [markdown]
# ## 4.4. XRP x BTC, ETH, BCH e LTC
#
# O terceiro caso de treinamento e teste foi verificar a capacidade da Ripple de descrever o comportamento das outras criptomoedas. Portanto, 5-NN (kNN com 5 vizinhos mais próximos) foi treinado com os dados de abertura, alta, baixa e fechamento da Ripple em uma dia $x$ e testado com os dados de fechamento das demais criptomoedas, também no dia $x$.

# %%
x_train = xrp.iloc[:,5:8]
y_train = xrp.iloc[:,8]

x_test = [btc.iloc[:,5:8], eth.iloc[:,5:8], bch.iloc[:,5:8], ltc.iloc[:,5:8]]
y_test = [btc.iloc[:,8],   eth.iloc[:,8], bch.iloc[:,8], ltc.iloc[:,8]]

clf = None
clf = KNeighborsRegressor(n_neighbors=5, weights='distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='distance')

# %%
results = []

for x, y in zip(x_test, y_test):
        y_pred = clf.predict(x)
        r2  = clf.score(x, y)
        mse = mean_squared_error(y, y_pred)
        evs = explained_variance_score(y, y_pred)
        aux = [r2, mse, evs, y_pred]
        results.append(aux)

# %%
for i in results:
    print('R²: {:.4f}\tMSE: {:.4f}\t EVS: {:.4f}'.format(i[0], i[1], i[2]))
# Out:
# R²: -0.3224	MSE: 14597990.8454	 EVS: -0.0000
# R²: -0.4385	MSE: 123274.4172	 EVS: 0.0016
# R²: -2.5744	MSE: 1685342.7931	 EVS: -0.0000
# R²: -0.2020	MSE: 3682.0759	 EVS: 0.0022

# %%
plt.figure(figsize=(15,7))
plt.plot(btc_dates, y_test[0],     color='#FFC312')
plt.plot(btc_dates, results[0][3], color='#0652DD')
plt.legend(['BTC (Close) Verdadeiro', 'BTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(eth_dates, y_test[1],     color='#2ecc71')
plt.plot(eth_dates, results[1][3], color='#0652DD')
plt.legend(['ETH (Close) Verdadeiro', 'ETH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(bch_dates, y_test[2],     color='#D980FA')
plt.plot(bch_dates, results[2][3], color='#0652DD')
plt.legend(['BCH (Close) Verdadeiro', 'BCH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(ltc_dates, y_test[3],     color='#EA2027')
plt.plot(ltc_dates, results[3][3], color='#0652DD')
plt.legend(['LTC (Close) Verdadeiro', 'LTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Resultados
#
# A Tabela abaixo apresenta os resultados obtidos no segundo caso
#
# | Criptomoeda | R Quadrado  | MSE          | EVS     |
# |-------------|-------------|--------------|---------|
# | Bitcoin     | -0.3224     | 14597900.8454| 0.0000  |
# | Ethereum    | -0.4385     | 123274.4172  | 0.0016  |
# | B.Cash      | -2.5744     | 1685342.7931 | 0.0000  |
# | Litecoin    | -0.2020     | 3682.0759    | 0.0022  |
#
#
# A Ripple é a pior criptomoeda para se ter qualquer estimativa quanto às outras sendo, a EVS a métrica com "melhor" desempenho.

# %% [markdown]
# ## 4.5. BCH x BTC, ETH, XRP e LTC
#
# O quarto caso de treinamento e teste foi verificar a capacidade do Bitcoin Cash de descrever o comportamento das outras criptomoedas. Portanto, 5-NN (kNN com 5 vizinhos mais próximos) foi treinado com os dados de abertura, alta, baixa e fechamento da Bitcoin Cash em uma dia $x$ e testado com os dados de fechamento das demais criptomoedas, também no dia $x$.

# %%
x_train = bch.iloc[:,5:8]
y_train = bch.iloc[:,8]

x_test = [btc.iloc[:,5:8], eth.iloc[:,5:8], xrp.iloc[:,5:8], ltc.iloc[:,5:8]]
y_test = [btc.iloc[:,8],   eth.iloc[:,8], xrp.iloc[:,8], ltc.iloc[:,8]]

clf = None
clf = KNeighborsRegressor(n_neighbors=5, weights='distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='distance')

# %%
results = []

for x, y in zip(x_test, y_test):
        y_pred = clf.predict(x)
        r2  = clf.score(x, y)
        mse = mean_squared_error(y, y_pred)
        evs = explained_variance_score(y, y_pred)
        aux = [r2, mse, evs, y_pred]
        results.append(aux)

# %%
for i in results:
    print('R²: {:.4f}\tMSE: {:.4f}\t EVS: {:.4f}'.format(i[0], i[1], i[2]))
# Out:
# R²: 0.3861	MSE: 6777050.9687	 EVS: 0.4524
# R²: 0.5449	MSE: 38998.3631	 EVS: 0.8295
# R²: -566010.5632	MSE: 67991.4419	 EVS: -0.0426
# R²: -17.6300	MSE: 57066.8912	 EVS: -0.0400

# %%
plt.figure(figsize=(15,7))
plt.plot(btc_dates, y_test[0],     color='#FFC312')
plt.plot(btc_dates, results[0][3], color='#D980FA')
plt.legend(['LTC (Close) Verdadeiro', 'LTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin Cash', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(eth_dates, y_test[1],     color='#2ecc71')
plt.plot(eth_dates, results[1][3], color='#D980FA')
plt.legend(['ETH (Close) Verdadeiro', 'ETH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin Cash', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(xrp_dates, y_test[2],     color='#0652DD')
plt.plot(xrp_dates, results[2][3], color='#D980FA')
plt.legend(['XRP (Close) Verdadeiro', 'XRP (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin Cash', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(ltc_dates, y_test[3],     color='#EA2027')
plt.plot(ltc_dates, results[3][3], color='#D980FA')
plt.legend(['LTC (Close) Verdadeiro', 'LTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Bitcoin Cash', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Resultados
#
# A Tabela abaixo apresenta os resultados obtidos no segundo caso
#
# | Criptomoeda | R Quadrado  | MSE          | EVS     |
# |-------------|-------------|--------------|---------|
# | Bitcoin     | 0.3861    | 6777050.9687|  0.4524  |
# | Ethereum    | 0.5449     |  38998.3631	  | 0.8295  |
# | Ripple      | -566010.5632    | 67991.4419 |  -0.0426  |
# | Litecoin    | -17.6300     | 57066.8912	   | -0.0400  |
#
#
# A partir BCH também é impossível obter qualquer boa estimativa sobre qualquer outra criptomoeda tal como a XRP

# %% [markdown]
# ## 4.6. LTC x BTC, ETH, XRP e BCH
#
# O último caso de treinamento e teste foi verificar a capacidade do Litecoin de descrever o comportamento das outras criptomoedas. Portanto, 5-NN (kNN com 5 vizinhos mais próximos) foi treinado com os dados de abertura, alta, baixa e fechamento da Litecoin em uma dia $x$ e testado com os dados de fechamento das demais criptomoedas, também no dia $x$.

# %%
x_train = ltc.iloc[:,5:8]
y_train = ltc.iloc[:,8]

x_test = [btc.iloc[:,5:8], eth.iloc[:,5:8], xrp.iloc[:,5:8], bch.iloc[:,5:8]]
y_test = [btc.iloc[:,8],   eth.iloc[:,8], xrp.iloc[:,8], bch.iloc[:,8]]

clf = None
clf = KNeighborsRegressor(n_neighbors=5, weights='distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='distance')

# %%
results = []

for x, y in zip(x_test, y_test):
        y_pred = clf.predict(x)
        r2  = clf.score(x, y)
        mse = mean_squared_error(y, y_pred)
        evs = explained_variance_score(y, y_pred)
        aux = [r2, mse, evs, y_pred]
        results.append(aux)

# %%
for i in results:
    print('R²: {:.4f}\tMSE: {:.4f}\t EVS: {:.4f}'.format(i[0], i[1], i[2]))
# Out:
# R²: -0.2202	MSE: 13469643.6053	 EVS: 0.0102
# R²: 0.5413	MSE: 39307.9318	 EVS: 0.6087
# R²: -11.6897	MSE: 1.5243	 EVS: 0.3548
# R²: -1.2766	MSE: 1073440.3074	 EVS: 0.0054

# %%
plt.figure(figsize=(15,7))
plt.plot(btc_dates, y_test[0],     color='#FFC312')
plt.plot(btc_dates, results[0][3], color='#EA2027')
plt.legend(['BTC (Close) Verdadeiro', 'BTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Litecoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(eth_dates, y_test[1],     color='#2ecc71')
plt.plot(eth_dates, results[1][3], color='#EA2027')
plt.legend(['ETH (Close) Verdadeiro', 'ETH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Litecoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(xrp_dates, y_test[2],     color='#0652DD')
plt.plot(xrp_dates, results[2][3], color='#EA2027')
plt.legend(['XRP (Close) Verdadeiro', 'XRP (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Litecoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(bch_dates, y_test[3],     color='#D980FA')
plt.plot(bch_dates, results[3][3], color='#EA2027')
plt.legend(['LTC (Close) Verdadeiro', 'LTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no Litecoin', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Normalização e Padronização dos Dados
#
# Uma questão que pode ser levantada quanto aos resultados obtidos pela XRP é que a diferença discrepante nos dados pode ter prejudicado o processo de treinamento do modelo o que o tornou incapaz de aprender.
#
# Para verificar tal fator, filtramos os dados

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler = MinMaxScaler()

x_train = scaler.fit_transform(xrp.iloc[:,5:8])
y_train = scaler.fit_transform(xrp.iloc[:,8].values.reshape((-1,1)))


x_test = [scaler.fit_transform(btc.iloc[:,5:8]), 
          scaler.fit_transform(eth.iloc[:,5:8]), 
          scaler.fit_transform(bch.iloc[:,5:8]), 
          scaler.fit_transform(ltc.iloc[:,5:8])]

y_test = [scaler.fit_transform(btc.iloc[:,8].values.reshape((-1,1))),
          scaler.fit_transform(eth.iloc[:,8].values.reshape((-1,1))),
          scaler.fit_transform(bch.iloc[:,8].values.reshape((-1,1))),
          scaler.fit_transform(ltc.iloc[:,8].values.reshape((-1,1)))]
          


clf = None
clf = KNeighborsRegressor(n_neighbors=5, weights='distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='distance')

# %%
results = []

for x, y in zip(x_test, y_test):
        y_pred = clf.predict(x)
        r2  = clf.score(x, y)
        mse = mean_squared_error(y, y_pred)
        evs = explained_variance_score(y, y_pred)
        aux = [r2, mse, evs, y_pred]
        results.append(aux)

# %%
for i in results:
    print('R²: {:.4f}\tMSE: {:.4f}\t EVS: {:.4f}'.format(i[0], i[1], i[2]))
# Out:
# R²: 0.9966	MSE: 0.0001	 EVS: 0.9967
# R²: 0.9948	MSE: 0.0002	 EVS: 0.9956
# R²: 0.9693	MSE: 0.0011	 EVS: 0.9797
# R²: 0.9956	MSE: 0.0001	 EVS: 0.9958

# %%
plt.figure(figsize=(15,7))
plt.plot(btc_dates, y_test[0],     color='#FFC312')
plt.plot(btc_dates, results[0][3], color='#0652DD')
plt.legend(['BTC (Close) Verdadeiro', 'BTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(eth_dates, y_test[1],     color='#2ecc71')
plt.plot(eth_dates, results[1][3], color='#0652DD')
plt.legend(['ETH (Close) Verdadeiro', 'ETH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(bch_dates, y_test[2],     color='#D980FA')
plt.plot(bch_dates, results[2][3], color='#0652DD')
plt.legend(['BCH (Close) Verdadeiro', 'BCH (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(ltc_dates, y_test[3],     color='#EA2027')
plt.plot(ltc_dates, results[3][3], color='#0652DD')
plt.legend(['LTC (Close) Verdadeiro', 'LTC (Close) Predito'], loc=0, fontsize='x-large')
plt.title('Curva verdadeira x Predita com base no XRP', fontsize='xx-large')
plt.xticks(rotation=90)
plt.show()

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(xrp.iloc[:,5:8])
y_train = scaler.fit_transform(xrp.iloc[:,8].values.reshape((-1,1)))


x_test = [scaler.fit_transform(btc.iloc[:,5:8]), 
          scaler.fit_transform(eth.iloc[:,5:8]), 
          scaler.fit_transform(bch.iloc[:,5:8]), 
          scaler.fit_transform(ltc.iloc[:,5:8])]

y_test = [scaler.fit_transform(btc.iloc[:,8].values.reshape((-1,1))),
          scaler.fit_transform(eth.iloc[:,8].values.reshape((-1,1))),
          scaler.fit_transform(bch.iloc[:,8].values.reshape((-1,1))),
          scaler.fit_transform(ltc.iloc[:,8].values.reshape((-1,1)))]
          


clf = None
clf = KNeighborsRegressor(n_neighbors=5, weights='distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='distance')

# %%
results = []

for x, y in zip(x_test, y_test):
        y_pred = clf.predict(x)
        r2  = clf.score(x, y)
        mse = mean_squared_error(y, y_pred)
        evs = explained_variance_score(y, y_pred)
        aux = [r2, mse, evs, y_pred]
        results.append(aux)

# %%
for i in results:
    print('R²: {:.4f}\tMSE: {:.4f}\t EVS: {:.4f}'.format(i[0], i[1], i[2]))
# Out:
# R²: 0.9927	MSE: 0.0073	 EVS: 0.9947
# R²: 0.9580	MSE: 0.0420	 EVS: 0.9816
# R²: 0.8585	MSE: 0.1415	 EVS: 0.9034
# R²: 0.9951	MSE: 0.0049	 EVS: 0.9965
